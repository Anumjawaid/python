# %% [markdown]
# # OOP Task

# %% [markdown]
# # Task

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Explanation

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Person():
    def __init__(me,initialage):
        me.initialage=initialage
        if(me.initialage<0):
            me.initialage=0
            print("Age is not valid setting age to zero")
        else:
            pass
            
        me.initialage=initialage
        
    def age(me):
        print(me.initialage)
    def yearPasses(me):
        me.initialage+=1
    def amIOld(me):
        age =me.initialage
        if(age<13):
            print("You are Young")
        elif(age>=13 and age<18):
            print("You are teenager")
        else:
            print("Y0u are old")

# %%
t = int(input())
for i in range(0, t):
    age = int(input())         
    p = Person(age)  
    p.amIOld()
    for j in range(0, 3):
        p.yearPasses()       
    p.amIOld()
    print("")
# Out:
# 4
# -1
# Age is not valid setting age to zero
# You are Young
# You are Young
#
# 10
# You are Young
# You are teenager
#
# 16
# You are teenager
# Y0u are old
#
# 18
# Y0u are old
# Y0u are old

# %%
class Person:
    def __init__(self,initialage):

        # Add some more code to run some checks on initialAge
        self.initialage=initialage
        if(self.initialage<0):
            self.initialage=0
            print("Age is not valid setting age to zero")
        else:
            pass
            
        self.initialage=initialage
    def amIOld(self):

        age =self.initialage
        if(age<13):
            print("You are Young")
        elif(age>=13 and age<18):
            print("You are teenager")
        else:
            print("Y0u are old")
        # Do some computations in here and print out the correct statement to the console
    def yearPasses(self):
        # Increment the age of the person in here
        self.initialage+=1

t = int(input())
for i in range(0, t):
    age = int(input())         
    p = Person(age)  
    p.amIOld()
    for j in range(0, 3):
        p.yearPasses()       
    p.amIOld()
    print("")
# Out:
# 4
# -1
# Age is not valid setting age to zero
# You are Young
# You are Young
#
# 10
# You are Young
# You are teenager
#
# 16
# You are teenager
# Y0u are old
#
# 18
# Y0u are old
# Y0u are old
